# %% [markdown]
# # **This colab converts yolo models into an onnx format ready to be converted to tensorrt, compatible with jetson nano**

# %% [markdown]
# Conect your google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive'),

# %% [markdown]
# Download your desired model

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10n.pt
# !wget https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt
# !wget https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5nu.pt

# %% [markdown]
# Install dependencies

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu102 --force-reinstall

# %%
pip install ultralytics

# %% [markdown]
# Convert the model

# %%
# !yolo export model=yolov10n.pt format=onnx opset=13 simplify
# !yolo export model=yolov8n.pt format=onnx opset=13 simplify
# !yolo export model=yolov5nu.pt format=onnx opset=13 simplify
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.11.8 torch-2.3.1 CPU (Apple M1)
# YOLOv6n summary (fused): 142 layers, 4495392 parameters, 0 gradients, 13.0 GFLOPs
#
# PyTorch: starting from 'yolov6n.yaml' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (0.0 MB)
#
# ONNX: starting export with onnx 1.13.0 opset 13...
# ONNX: slimming with onnxslim 0.1.28...
# ONNX: simplifier failure: type object 'TensorProto' has no attribute 'FLOAT8E4M3FN'
# ONNX: export success ✅ 2.4s, saved as 'yolov6n.onnx' (17.3 MB)
#
# Export complete (3.9s)
# Results saved to /Users/jason/programming/personal_projects/jetson_nano_ubuntu20_docker/yolo
# Predict:         yolo predict task=detect model=yolov6n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov6n.onnx imgsz=640 data=None
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export
